# %%
pip install aixplain
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from aixplain.factories import AgentFactory

agent = AgentFactory.create(
    name="Dawah-GPT",
    description="An AI assistant that helps Muslims give dawah.",
    instructions="Answer the user's questions accurately."
)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from aixplain.factories import AgentFactory
#       3 agent = AgentFactory.create(
#       4     name="Dawah-GPT",
#       5     description="An AI assistant that helps Muslims give dawah.",
#       6     instructions="Answer the user's questions accurately."
#       7 )
#
# File /opt/homebrew/lib/python3.11/site-packages/aixplain/factories/__init__.py:22
#       1 """
#       2 aiXplain SDK Library.
#       3 ---
#    (...)     20 limitations under the License.
#      21 """
# ---> 22 from .asset_factory import AssetFactory
#      23 from .agent_factory import AgentFactory
#      24 from .team_agent_factory import TeamAgentFactory
#
# File /opt/homebrew/lib/python3.11/site-packages/aixplain/factories/asset_factory.py:26
#      24 from abc import abstractmethod
#      25 from typing import Text
# ...
